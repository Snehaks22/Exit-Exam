# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder,OrdinalEncoder
from sklearn.model_selection import train_test_split

# %%
df_train=pd.read_csv("C:\\Users\\steph\\Downloads\\Train.csv")
df_train
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female            0.0     Yes         No     1.0
# 1     5575-GNVDE    Male            0.0      No         No    34.0
# 2     3668-QPYBK    Male            0.0      No         No     2.0
# 3     7795-CFOCW    Male            0.0      No         No    45.0
# 4     9237-HQITU  Female            0.0      No         No     2.0
# ...          ...     ...            ...     ...        ...     ...
# 5630  9801-GDWGV  Female            0.0      No         No    39.0
# 5631  6542-LWGXJ    Male            0.0     Yes         No     3.0
# 5632  5567-GZKQY    Male            0.0      No         No    58.0
# 5633  1222-LRYKO    Male            0.0      No        Yes     6.0
# 5634  2320-JRSDE  Female            0.0     Yes        Yes     1.0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 0              No  No phone service             DSL                   No  ...
# ...

# %%
df_test = pd.DataFrame(pd.read_excel("C:\\Users\\steph\\Downloads\\test.xlsx")) 
df_test
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     2087-QAREY  Female              0     Yes         No    22.0
# 1     0601-WZHJF    Male              0     Yes         No    14.0
# 2     4423-JWZJN    Male              0     Yes        Yes    64.0
# 3     5143-WMWOG    Male              0      No         No     1.0
# 4     6490-FGZAT    Male              0      No         No     6.0
# ...          ...     ...            ...     ...        ...     ...
# 1403  6840-RESVB    Male              0     Yes        Yes    24.0
# 1404  2234-XADUH  Female              0     Yes        Yes    72.0
# 1405  4801-JZAZL  Female              0     Yes        Yes    11.0
# 1406  8361-LTMKD    Male              1     Yes         No     4.0
# 1407  3186-AJIEK    Male              0      No         No    66.0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  \
# 0             Yes                No             DSL                   No
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5635 entries, 0 to 5634
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        5635 non-null   object
#  1   gender            5635 non-null   object
#  2   SeniorCitizen     5628 non-null   float64
#  3   Partner           5635 non-null   object
#  4   Dependents        5635 non-null   object
#  5   tenure            5622 non-null   float64
#  6   PhoneService      5622 non-null   object
#  7   MultipleLines     5622 non-null   object
#  8   InternetService   5598 non-null   object
#  9   OnlineSecurity    5620 non-null   object
#  10  OnlineBackup      5620 non-null   object
#  11  DeviceProtection  5620 non-null   object
#  12  TechSupport       5620 non-null   object
#  13  StreamingTV       5613 non-null   object
#  14  StreamingMovies   5621 non-null   object
#  15  Contract          5610 non-null   object
# ...

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1408 entries, 0 to 1407
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        1408 non-null   object
#  1   gender            1408 non-null   object
#  2   SeniorCitizen     1408 non-null   int64
#  3   Partner           1408 non-null   object
#  4   Dependents        1408 non-null   object
#  5   tenure            1400 non-null   float64
#  6   PhoneService      1397 non-null   object
#  7   MultipleLines     1396 non-null   object
#  8   InternetService   1400 non-null   object
#  9   OnlineSecurity    1400 non-null   object
#  10  OnlineBackup      1400 non-null   object
#  11  DeviceProtection  1398 non-null   object
#  12  TechSupport       1398 non-null   object
#  13  StreamingTV       1400 non-null   object
#  14  StreamingMovies   1393 non-null   object
#  15  Contract          1393 non-null   object
# ...

# %%
df_train.shape
# Out:
# (5635, 21)

# %%
df_test.shape
# Out:
# (1408, 20)

# %%
# Checking for duplicate columns.
df_train.duplicated().sum()
# Out:
# 0

# %%
df_test.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicate columns in both test and train data.

# %%
df_train = df_train.drop(['customerID'], axis = 1)
df_train.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female            0.0     Yes         No     1.0           No
# 1    Male            0.0      No         No    34.0          Yes
# 2    Male            0.0      No         No     2.0          Yes
# 3    Male            0.0      No         No    45.0           No
# 4  Female            0.0      No         No     2.0          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
df_test = df_test.drop(['customerID'], axis = 1)
df_test.head()
# Out:
#      tenure  MonthlyCharges  TotalCharges  gender  SeniorCitizen  Partner  \
# 0  0.305556        0.362770      0.134073       0              0        1
# 1  0.194444        0.278976      0.075001       1              0        1
# 2  0.888889        0.719518      0.648496       1              0        1
# 3  0.013889        0.014049      0.000127       1              0        0
# 4  0.083333        0.021074      0.010455       1              0        0
#
#    Dependents  PhoneService  MultipleLines  InternetService  OnlineSecurity  \
# 0           0             1              0                0               0
# 1           0             0              1                0               0
# 2           1             1              2                1               0
# 3           0             1              0                2               1
# 4           0             1              0                2               1
#
# ...

# %%
df_train['TotalCharges'] = pd.to_numeric(df_train.TotalCharges, errors='coerce')

# %%
df_test['TotalCharges'] = pd.to_numeric(df_test.TotalCharges, errors='coerce')

# %%
df_train["SeniorCitizen"]= df_train["SeniorCitizen"].map({0: "No", 1: "Yes"})
df_train.head()
# Out:
#    gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female            No     Yes         No     1.0           No
# 1    Male            No      No         No    34.0          Yes
# 2    Male            No      No         No     2.0          Yes
# 3    Male            No      No         No    45.0           No
# 4  Female            No      No         No     2.0          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
df_test["SeniorCitizen"]= df_test["SeniorCitizen"].map({0: "No", 1: "Yes"})
df_test.head()
# Out:
#    customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  2087-QAREY  Female            No     Yes         No    22.0          Yes
# 1  0601-WZHJF    Male            No     Yes         No    14.0           No
# 2  4423-JWZJN    Male            No     Yes        Yes    64.0          Yes
# 3  5143-WMWOG    Male            No      No         No     1.0          Yes
# 4  6490-FGZAT    Male            No      No         No     6.0          Yes
#
#       MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
# 0                No             DSL                   No                  Yes
# 1  No phone service             DSL                   No                   No
# 2               Yes     Fiber optic                   No                   No
# 3                No              No  No internet service  No internet service
# 4                No              No  No internet service  No internet service
#
# ...

# %%
df_train.describe()
# Out:
#             tenure  MonthlyCharges  TotalCharges
# count  5622.000000     5619.000000   5619.000000
# mean     32.286375       64.854983   2281.382968
# std      24.591460       30.105189   2268.261114
# min       0.000000       18.250000     18.800000
# 25%       9.000000       35.550000    392.900000
# 50%      29.000000       70.400000   1400.300000
# 75%      55.000000       89.900000   3772.575000
# max      72.000000      118.750000   8684.800000

# %%
df_test.describe()
# Out:
#             tenure  MonthlyCharges  TotalCharges
# count  1400.000000      1400.00000   1406.000000
# mean     32.732143        64.31600   2290.609068
# std      24.449954        30.05609   2261.076774
# min       0.000000        18.55000     18.850000
# 25%       9.000000        35.27500    418.325000
# 50%      30.000000        70.10000   1386.900000
# 75%      56.000000        89.61250   3835.150000
# max      72.000000       118.20000   8670.100000

# %% [markdown]
# ##### Handling missing values in train data.

# %%
df_train.isnull().sum()
# Out:
# gender               0
# SeniorCitizen        7
# Partner              0
# Dependents           0
# tenure              13
# PhoneService        13
# MultipleLines       13
# InternetService     37
# OnlineSecurity      15
# OnlineBackup        15
# DeviceProtection    15
# TechSupport         15
# StreamingTV         22
# StreamingMovies     14
# Contract            25
# PaperlessBilling    14
# PaymentMethod        1
# MonthlyCharges      16
# TotalCharges        16
# Churn                0
# dtype: int64

# %%
num_df_train=df_train.select_dtypes(include="number")
cat_df_train=df_train.select_dtypes(include="object_")

# %%
print("Numerical columns are")
train_num_cols =num_df_train.columns.tolist()
print(train_num_cols)

print("Categorical columns are")
train_cat_cols =cat_df_train.columns.tolist()
print(train_cat_cols)
# Out:
# Numerical columns are
# ['tenure', 'MonthlyCharges', 'TotalCharges']
# Categorical columns are
# ['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'Churn']

# %%
for col in train_num_cols:
    num_df_train[col]=num_df_train[col].fillna(num_df_train[col].median())

# %%
num_df_train.isna().sum()
# Out:
# tenure            0
# MonthlyCharges    0
# TotalCharges      0
# dtype: int64

# %%
for col in train_cat_cols:
    cat_df_train[col]=cat_df_train[col].fillna(cat_df_train[col].mode()[0])

# %%
cat_df_train.isna().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# Churn               0
# dtype: int64

# %%
df_train = pd.concat([num_df_train,cat_df_train], axis=1)

# %%
df_train.isnull().sum()
# Out:
# tenure              0
# MonthlyCharges      0
# TotalCharges        0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# Churn               0
# dtype: int64

# %% [markdown]
# ##### Handling missing values in test data.

# %%
df_test.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               8
# PhoneService        11
# MultipleLines       12
# InternetService      8
# OnlineSecurity       8
# OnlineBackup         8
# DeviceProtection    10
# TechSupport         10
# StreamingTV          8
# StreamingMovies     15
# Contract            15
# PaperlessBilling    15
# PaymentMethod        8
# MonthlyCharges       8
# TotalCharges         2
# dtype: int64

# %%
num_df_test=df_test.select_dtypes(include="number")
cat_df_test=df_test.select_dtypes(include="object_")

# %%
print("Numerical columns are")
test_num_cols =num_df_test.columns.tolist()
print(test_num_cols)

print("Categorical columns are")
test_cat_cols =cat_df_test.columns.tolist()
print(test_cat_cols)
# Out:
# Numerical columns are
# ['tenure', 'MonthlyCharges', 'TotalCharges']
# Categorical columns are
# ['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod']

# %%
for col in test_num_cols:
    num_df_test[col]=num_df_test[col].fillna(num_df_test[col].median())

num_df_test.isna().sum()
# Out:
# tenure            0
# MonthlyCharges    0
# TotalCharges      0
# dtype: int64

# %%
for col in test_cat_cols:
    cat_df_test[col]=cat_df_test[col].fillna(cat_df_test[col].mode()[0])

cat_df_test.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# dtype: int64

# %%
df_test = pd.concat([num_df_test,cat_df_test], axis=1)
df_test.isnull().sum()
# Out:
# tenure              0
# MonthlyCharges      0
# TotalCharges        0
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# dtype: int64

# %% [markdown]
# ##### Checking for Outlier

# %%
num_df_train.boxplot()
plt.show()

# %%
num_df_test.boxplot()
plt.show()

# %%
for col in num_df_train:
    plt.hist(num_df_train[col])
    plt.title("Distribution of {} ".format(col))
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()

# %%
for col in num_df_test:
    plt.hist(num_df_test[col])
    plt.title("Distribution of {} ".format(col))
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()

# %%
sns.heatmap(num_df_train.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# * Tenure and Total Charges are Highly correlated.
# * Monthly Charges and Total Charges are also correlated.

# %%
df_train["Churn"][df_train["Churn"]=="No"].groupby(by=df_train["gender"]).count()
# Out:
# gender
# Female    2038
# Male      2108
# Name: Churn, dtype: int64

# %%
df_train["Churn"][df_train["Churn"]=="Yes"].groupby(by=df_train["gender"]).count()
# Out:
# gender
# Female    754
# Male      735
# Name: Churn, dtype: int64

# %%
fig = px.histogram(df_train, x="Churn", color="Contract", barmode="group", title="<b>Customer contract distribution<b>")
fig.update_layout(width=700, height=500, bargap=0.1)
fig.show()

# %% [markdown]
# ##### Scaling

# %%
# Scaling in train data.
min_max_scalar= MinMaxScaler(feature_range=(0,1))
df_train[['tenure', 'MonthlyCharges', 'TotalCharges']] = min_max_scalar.fit_transform(df_train[['tenure', 'MonthlyCharges', 'TotalCharges']])
df_train.head()
# Out:
#      tenure  MonthlyCharges  TotalCharges  gender SeniorCitizen Partner  \
# 0  0.013889        0.115423      0.001275  Female            No     Yes
# 1  0.472222        0.385075      0.215867    Male            No      No
# 2  0.027778        0.354229      0.010310    Male            No      No
# 3  0.625000        0.239303      0.210241    Male            No      No
# 4  0.027778        0.521891      0.015330  Female            No      No
#
#   Dependents PhoneService     MultipleLines InternetService OnlineSecurity  \
# 0         No           No  No phone service             DSL             No
# 1         No          Yes                No             DSL            Yes
# 2         No          Yes                No             DSL            Yes
# 3         No           No  No phone service             DSL            Yes
# 4         No          Yes                No     Fiber optic             No
#
#   OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies  \
# ...

# %%
# Checking for Unique values in Categorical columns.
print(pd.unique(cat_df_train['gender']))
print(pd.unique(cat_df_train['Partner']))
print(pd.unique(cat_df_train['Dependents']))
print(pd.unique(cat_df_train['PhoneService']))
print(pd.unique(cat_df_train['MultipleLines']))
print(pd.unique(cat_df_train['InternetService']))
print(pd.unique(cat_df_train['OnlineSecurity']))
print(pd.unique(cat_df_train['OnlineBackup']))
print(pd.unique(cat_df_train['DeviceProtection']))
print(pd.unique(cat_df_train['TechSupport']))
print(pd.unique(cat_df_train['StreamingTV']))
print(pd.unique(cat_df_train['StreamingMovies']))
print(pd.unique(cat_df_train['Contract']))
print(pd.unique(cat_df_train['PaperlessBilling']))
print(pd.unique(cat_df_train['PaymentMethod']))
print(pd.unique(cat_df_train['Churn']))
print(pd.unique(num_df_train['SeniorCitizen']))
# Out:
# ['Female' 'Male']
# ['Yes' 'No']
# ['No' 'Yes']
# ['No' 'Yes']
# ['No phone service' 'No' 'Yes']
# ['DSL' 'Fiber optic' 'No']
# ['No' 'Yes' 'No internet service']
# ['Yes' 'No' 'No internet service']
# ['No' 'Yes' 'No internet service']
# ['No' 'Yes' 'No internet service']
# ['No' 'Yes' 'No internet service']
# ['No' 'Yes' 'No internet service']
# ['Month-to-month' 'One year' 'Two year']
# ['Yes' 'No']
# ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# ['No' 'Yes']
# [0. 1.]

# %% [markdown]
# ##### Encoding

# %%
# Encoding in train data
label_enc = LabelEncoder()
df_train['gender'] = label_enc.fit_transform(df_train['gender'])
df_train['Partner'] = label_enc.fit_transform(df_train['Partner'])
df_train['Dependents'] = label_enc.fit_transform(df_train['Dependents'])
df_train['PhoneService'] = label_enc.fit_transform(df_train['PhoneService'])
df_train['MultipleLines'] = label_enc.fit_transform(df_train['MultipleLines'])
df_train['InternetService'] = label_enc.fit_transform(df_train['InternetService'])
df_train['OnlineSecurity'] = label_enc.fit_transform(df_train['OnlineSecurity'])
df_train['OnlineBackup'] = label_enc.fit_transform(df_train['OnlineBackup'])
df_train['DeviceProtection'] = label_enc.fit_transform(df_train['DeviceProtection'])
df_train['TechSupport'] = label_enc.fit_transform(df_train['TechSupport'])
df_train['StreamingTV'] = label_enc.fit_transform(df_train['StreamingTV'])
df_train['StreamingMovies'] = label_enc.fit_transform(df_train['StreamingMovies'])
df_train['Contract'] = label_enc.fit_transform(df_train['Contract'])
df_train['PaperlessBilling'] = label_enc.fit_transform(df_train['PaperlessBilling'])
df_train['PaymentMethod'] = label_enc.fit_transform(df_train['PaymentMethod'])
df_train['SeniorCitizen'] = label_enc.fit_transform(df_train['SeniorCitizen'])
df_train['Churn'] = label_enc.fit_transform(df_train['Churn'])

df_train
# Out:
#         tenure  MonthlyCharges  TotalCharges  gender  SeniorCitizen  Partner  \
# 0     0.013889        0.115423      0.001275       0              0        1
# 1     0.472222        0.385075      0.215867       1              0        0
# 2     0.027778        0.354229      0.010310       1              0        0
# 3     0.625000        0.239303      0.210241       1              0        0
# 4     0.027778        0.521891      0.015330       0              0        0
# ...        ...             ...           ...     ...            ...      ...
# 5630  0.541667        0.847761      0.458764       0              0        0
# 5631  0.041667        0.067164      0.006860       1              0        1
# 5632  0.805556        0.020398      0.128398       1              0        0
# 5633  0.083333        0.080597      0.019069       1              0        0
# 5634  0.013889        0.016418      0.000127       0              0        1
#
# ...

# %%
# Scaling in test data.
min_max_scalar= MinMaxScaler(feature_range=(0,1))
df_test[['tenure', 'MonthlyCharges', 'TotalCharges']] = min_max_scalar.fit_transform(df_test[['tenure', 'MonthlyCharges', 'TotalCharges']])
df_test.head()
# Out:
#      tenure  MonthlyCharges  TotalCharges  customerID  gender SeniorCitizen  \
# 0  0.305556        0.362770      0.134073  2087-QAREY  Female            No
# 1  0.194444        0.278976      0.075001  0601-WZHJF    Male            No
# 2  0.888889        0.719518      0.648496  4423-JWZJN    Male            No
# 3  0.013889        0.014049      0.000127  5143-WMWOG    Male            No
# 4  0.083333        0.021074      0.010455  6490-FGZAT    Male            No
#
#   Partner Dependents PhoneService     MultipleLines InternetService  \
# 0     Yes         No          Yes                No             DSL
# 1     Yes         No           No  No phone service             DSL
# 2     Yes        Yes          Yes               Yes     Fiber optic
# 3      No         No          Yes                No              No
# 4      No         No          Yes                No              No
#
#         OnlineSecurity         OnlineBackup     DeviceProtection  \
# ...

# %%
# Encoding in test data.
label_enc = LabelEncoder()
df_test['gender'] = label_enc.fit_transform(df_test['gender'])
df_test['Partner'] = label_enc.fit_transform(df_test['Partner'])
df_test['Dependents'] = label_enc.fit_transform(df_test['Dependents'])
df_test['PhoneService'] = label_enc.fit_transform(df_test['PhoneService'])
df_test['MultipleLines'] = label_enc.fit_transform(df_test['MultipleLines'])
df_test['InternetService'] = label_enc.fit_transform(df_test['InternetService'])
df_test['OnlineSecurity'] = label_enc.fit_transform(df_test['OnlineSecurity'])
df_test['OnlineBackup'] = label_enc.fit_transform(df_test['OnlineBackup'])
df_test['DeviceProtection'] = label_enc.fit_transform(df_test['DeviceProtection'])
df_test['TechSupport'] = label_enc.fit_transform(df_test['TechSupport'])
df_test['StreamingTV'] = label_enc.fit_transform(df_test['StreamingTV'])
df_test['StreamingMovies'] = label_enc.fit_transform(df_test['StreamingMovies'])
df_test['Contract'] = label_enc.fit_transform(df_test['Contract'])
df_test['PaperlessBilling'] = label_enc.fit_transform(df_test['PaperlessBilling'])
df_test['PaymentMethod'] = label_enc.fit_transform(df_test['PaymentMethod'])
df_test['SeniorCitizen'] = label_enc.fit_transform(df_test['SeniorCitizen'])

df_test
# Out:
#         tenure  MonthlyCharges  TotalCharges  gender  SeniorCitizen  Partner  \
# 0     0.305556        0.362770      0.134073       0              0        1
# 1     0.194444        0.278976      0.075001       1              0        1
# 2     0.888889        0.719518      0.648496       1              0        1
# 3     0.013889        0.014049      0.000127       1              0        0
# 4     0.083333        0.021074      0.010455       1              0        0
# ...        ...             ...           ...     ...            ...      ...
# 1403  0.333333        0.664827      0.227903       1              0        1
# 1404  1.000000        0.849473      0.848900       0              0        1
# 1405  0.152778        0.110888      0.037867       0              0        1
# 1406  0.055556        0.560462      0.033261       1              1        1
# 1407  0.916667        0.874059      0.788978       1              0        0
#
# ...

# %% [markdown]
# ##### Model Building

# %%
y=df_train['Churn'] 
X=df_train.drop('Churn',axis=1)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import accuracy_score,precision_score,f1_score,recall_score

# %%
log_model = LogisticRegression()
log_model.fit(X_train,y_train)
y_pred=log_model.predict(X_test)

# %%
accuracy=accuracy_score(y_test,y_pred)
f1 = f1_score(y_pred, y_test, average="weighted")
recall = recall_score(y_pred, y_test, average="weighted")
precision = precision_score(y_pred, y_test, average="weighted")
print(f"Accuracy:{accuracy}")
print("F1 Score:", f1)
print("Recall:", recall)
print("Precision:", precision)
# Out:
# Accuracy:0.8003549245785271
# F1 Score: 0.8073402990764377
# Recall: 0.8003549245785271
# Precision: 0.8186510736684129

# %%
knn_model = KNeighborsClassifier(n_neighbors = 11) 
knn_model.fit(X_train,y_train)
predicted_y = knn_model.predict(X_test)
accuracy_knn = knn_model.score(X_test,y_test)
print("KNN accuracy:",accuracy_knn)
# Out:
# KNN accuracy: 0.7533274179236912

# %%
clf = RandomForestClassifier(n_estimators = 100)  
 
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

accuracy = accuracy_score(y_pred, y_test)
f1 = f1_score(y_pred, y_test, average="weighted")
recall = recall_score(y_pred, y_test, average="weighted")
precision = precision_score(y_pred, y_test, average="weighted")

print("Accuracy:", accuracy)
print("F1 Score:", f1)
print("Recall:", recall)
print("Precision:", precision)
# Out:
# Accuracy: 0.7950310559006211
# F1 Score: 0.8037147767600594
# Recall: 0.7950310559006211
# Precision: 0.8182459970121828

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

rf = RandomForestClassifier(random_state=42)

param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'bootstrap': [True, False]
}


grid_search = GridSearchCV(rf, param_grid, cv=5, scoring='accuracy', n_jobs=-1)
grid_search.fit(X_train, y_train)

print("Best Parameters (GridSearchCV):", grid_search.best_params_)
best_rf_grid = grid_search.best_estimator_
y_pred_grid = best_rf_grid.predict(X_test)
print("Test Accuracy (GridSearchCV):", accuracy_score(y_test, y_pred_grid))

param_dist = {
    'n_estimators': np.arange(50, 300, 50),
    'max_depth': [None, 10, 20, 30, 40],
    'min_samples_split': np.arange(2, 11, 2),
    'min_samples_leaf': np.arange(1, 5),
    'bootstrap': [True, False]
}

random_search = RandomizedSearchCV(rf, param_dist, n_iter=20, cv=5, scoring='accuracy', n_jobs=-1, random_state=42)
random_search.fit(X_train, y_train)

print("Best Parameters (RandomizedSearchCV):", random_search.best_params_)
best_rf_random = random_search.best_estimator_
y_pred_random = best_rf_random.predict(X_test)
print("Test Accuracy (RandomizedSearchCV):", accuracy_score(y_test, y_pred_random))
